# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
z= files.upload()
# Out:
#      <input type="file" id="files-1b4c3d6f-7657-4ec8-b2ab-b0206b05df3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b4c3d6f-7657-4ec8-b2ab-b0206b05df3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dset3= pd.read_csv("two-winding-transformer-2021.csv")
dset3.head()
# Out:
#     Area        GSP Group  Node 1  Operating Voltage 1   Node 2  \
# 0  EMIDS  Berkswell 132kV  COVC1J                  132  COVC3 X
# 1  EMIDS  Berkswell 132kV  COVC1K                  132  COVC3 Y
# 2  EMIDS  Berkswell 132kV  COVS1J                  132  COVS3 X
# 3  EMIDS  Berkswell 132kV  COVS1K                  132  COVS3 Y
# 4  EMIDS  Berkswell 132kV  COVS1L                  132  COVS55J
#
#   Operating Voltage 2 Status Vector Group     R1      X1      X0  Min Tap %  \
# 0                  33    New          xd1  0.503  18.666  15.870      -20.0
# 1                  33    New          xd1  0.502  18.583  15.799      -20.0
# 2                  33    New          xd1  0.394  15.133  17.000      -20.0
# 3                  33    New          xd1  0.394  15.133  17.000      -20.0
# 4                  11    New          xx0  2.241  96.933  82.393      -20.0
#
#    Max Tap %  Nominal Rating  Emergency Rating Reverse Power Capability  \
# ...

# %%
dset3.tail()
# Out:
#        Area         GSP Group    Node 1  Operating Voltage 1    Node 2  \
# 2576  WMIDS  Willenhall 132kV  WILL GT2                  132  WILL112B
# 2577  WMIDS  Willenhall 132kV  WILL GT4                  132  WILL114B
# 2578  WMIDS  Willenhall 132kV  WILL GT1                  132  WILL111A
# 2579  WMIDS  Willenhall 132kV  WOLV tmp                  132   WOLV T3
# 2580  WMIDS  Willenhall 132kV  WOLV33 3                   33  WOLV11 5
#
#      Operating Voltage 2     Status Vector Group     R1      X1      X0  \
# 2576                  11  Unchanged          xd1  2.420  85.130  79.000
# 2577                  11  Unchanged          xd1  2.594  69.170  69.170
# 2578                  11  Unchanged          xd1  2.200  90.633  84.067
# 2579                  33  Unchanged          xd1  0.992  21.467  21.467
# 2580                  11  Unchanged          yy0  2.881  76.852   0.000
#
#       Min Tap %  Max Tap %  Nominal Rating  Emergency Rating  \
# ...

# %%
print(dset3.shape)
# Out:
# (2581, 17)

# %%
dset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2581 entries, 0 to 2580
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Area                      2581 non-null   object
#  1   GSP Group                 2581 non-null   object
#  2   Node 1                    2581 non-null   object
#  3   Operating Voltage 1       2581 non-null   int64
#  4   Node 2                    2581 non-null   object
#  5   Operating Voltage 2       2581 non-null   object
#  6   Status                    2581 non-null   object
#  7   Vector Group              2571 non-null   object
#  8   R1                        2581 non-null   float64
#  9   X1                        2581 non-null   float64
#  10  X0                        2581 non-null   float64
#  11  Min Tap %                 2581 non-null   float64
#  12  Max Tap %                 2581 non-null   float64
# ...

# %% [markdown]
# <h1> Method of Earthing is the Target variable </h1>

# %%
dset3.rename(columns = {'Method of Earthing':'Method_of_Earthing'}, inplace = True)

# %%
dset3.isnull()
# Out:
#        Area  GSP Group  Node 1  Operating Voltage 1  Node 2  \
# 0     False      False   False                False   False
# 1     False      False   False                False   False
# 2     False      False   False                False   False
# 3     False      False   False                False   False
# 4     False      False   False                False   False
# ...     ...        ...     ...                  ...     ...
# 2576  False      False   False                False   False
# 2577  False      False   False                False   False
# 2578  False      False   False                False   False
# 2579  False      False   False                False   False
# 2580  False      False   False                False   False
#
#       Operating Voltage 2  Status  Vector Group     R1     X1     X0  \
# 0                   False   False         False  False  False  False
# 1                   False   False         False  False  False  False
# ...

# %%
dset3.isnull().sum().sum()
# Out:
# 394

# %%
dset3.describe()
# Out:
#        Operating Voltage 1           R1           X1            X0  \
# count          2581.000000  2581.000000  2581.000000   2581.000000
# mean             56.589694     5.407874    89.277832    270.191583
# std              40.781097     3.752275    36.034226   3930.871809
# min              33.000000     0.000000     0.196000   -103.768000
# 25%              33.000000     2.823000    75.591000     21.219000
# 50%              33.000000     4.995000    97.405000     80.294000
# 75%              66.000000     6.779000   111.120000    104.178000
# max             132.000000    32.789000   283.000000  99900.000000
#
#          Min Tap %    Max Tap %  Nominal Rating  Emergency Rating
# count  2581.000000  2581.000000     2559.000000       2555.000000
# mean    -15.785819     5.602983       25.741145         31.381969
# std       3.524142     3.418595       22.764294         27.233453
# min     -24.000000   -20.000000        1.000000          3.000000
# ...

# %%
import missingno as mo
mo.matrix(dset3)
# Out:
# <Axes: >

# %%
print(dset3.columns[dset3.isna().any()])
# Out:
# Index(['Vector Group', 'Nominal Rating', 'Emergency Rating',
#        'Reverse Power Capability'],
#       dtype='object')

# %%
dset3.count()["Area"]
# Out:
# 2581

# %% [markdown]
# <h1> Filling Null values </h1>

# %%
print(dset3.isnull().sum())
# Out:
# Area                          0
# GSP Group                     0
# Node 1                        0
# Operating Voltage 1           0
# Node 2                        0
# Operating Voltage 2           0
# Status                        0
# Vector Group                 10
# R1                            0
# X1                            0
# X0                            0
# Min Tap %                     0
# Max Tap %                     0
# Nominal Rating               22
# Emergency Rating             26
# Reverse Power Capability    336
# Method_of_Earthing            0
# dtype: int64

# %%
tID= dset3["Nominal Rating"].mode()[0]
print("tID= ", tID)
dset3["Nominal Rating"].fillna(tID, inplace= True)
dset3.head()
# Out:
# tID=  18.0
#     Area        GSP Group  Node 1  Operating Voltage 1   Node 2  \
# 0  EMIDS  Berkswell 132kV  COVC1J                  132  COVC3 X
# 1  EMIDS  Berkswell 132kV  COVC1K                  132  COVC3 Y
# 2  EMIDS  Berkswell 132kV  COVS1J                  132  COVS3 X
# 3  EMIDS  Berkswell 132kV  COVS1K                  132  COVS3 Y
# 4  EMIDS  Berkswell 132kV  COVS1L                  132  COVS55J
#
#   Operating Voltage 2 Status Vector Group     R1      X1      X0  Min Tap %  \
# 0                  33    New          xd1  0.503  18.666  15.870      -20.0
# 1                  33    New          xd1  0.502  18.583  15.799      -20.0
# 2                  33    New          xd1  0.394  15.133  17.000      -20.0
# 3                  33    New          xd1  0.394  15.133  17.000      -20.0
# 4                  11    New          xx0  2.241  96.933  82.393      -20.0
#
#    Max Tap %  Nominal Rating  Emergency Rating Reverse Power Capability  \
# ...

# %%
tID= dset3["Emergency Rating"].mode()[0]
print("tID= ", tID)
dset3["Emergency Rating"].fillna(tID, inplace= True)
dset3.head()
# Out:
# tID=  24.0
#     Area        GSP Group  Node 1  Operating Voltage 1   Node 2  \
# 0  EMIDS  Berkswell 132kV  COVC1J                  132  COVC3 X
# 1  EMIDS  Berkswell 132kV  COVC1K                  132  COVC3 Y
# 2  EMIDS  Berkswell 132kV  COVS1J                  132  COVS3 X
# 3  EMIDS  Berkswell 132kV  COVS1K                  132  COVS3 Y
# 4  EMIDS  Berkswell 132kV  COVS1L                  132  COVS55J
#
#   Operating Voltage 2 Status Vector Group     R1      X1      X0  Min Tap %  \
# 0                  33    New          xd1  0.503  18.666  15.870      -20.0
# 1                  33    New          xd1  0.502  18.583  15.799      -20.0
# 2                  33    New          xd1  0.394  15.133  17.000      -20.0
# 3                  33    New          xd1  0.394  15.133  17.000      -20.0
# 4                  11    New          xx0  2.241  96.933  82.393      -20.0
#
#    Max Tap %  Nominal Rating  Emergency Rating Reverse Power Capability  \
# ...

# %%
tID= dset3["Vector Group"].mode()[0]
print("tID= ", tID)
dset3["Vector Group"].fillna(tID, inplace= True)
dset3.head()
# Out:
# tID=  dx11
#     Area        GSP Group  Node 1  Operating Voltage 1   Node 2  \
# 0  EMIDS  Berkswell 132kV  COVC1J                  132  COVC3 X
# 1  EMIDS  Berkswell 132kV  COVC1K                  132  COVC3 Y
# 2  EMIDS  Berkswell 132kV  COVS1J                  132  COVS3 X
# 3  EMIDS  Berkswell 132kV  COVS1K                  132  COVS3 Y
# 4  EMIDS  Berkswell 132kV  COVS1L                  132  COVS55J
#
#   Operating Voltage 2 Status Vector Group     R1      X1      X0  Min Tap %  \
# 0                  33    New          xd1  0.503  18.666  15.870      -20.0
# 1                  33    New          xd1  0.502  18.583  15.799      -20.0
# 2                  33    New          xd1  0.394  15.133  17.000      -20.0
# 3                  33    New          xd1  0.394  15.133  17.000      -20.0
# 4                  11    New          xx0  2.241  96.933  82.393      -20.0
#
#    Max Tap %  Nominal Rating  Emergency Rating Reverse Power Capability  \
# ...

# %%
tID= dset3["Reverse Power Capability"].mode()[0]
print("tID= ", tID)
dset3["Reverse Power Capability"].fillna(tID, inplace= True)
dset3.head()
# Out:
# tID=  -
#     Area        GSP Group  Node 1  Operating Voltage 1   Node 2  \
# 0  EMIDS  Berkswell 132kV  COVC1J                  132  COVC3 X
# 1  EMIDS  Berkswell 132kV  COVC1K                  132  COVC3 Y
# 2  EMIDS  Berkswell 132kV  COVS1J                  132  COVS3 X
# 3  EMIDS  Berkswell 132kV  COVS1K                  132  COVS3 Y
# 4  EMIDS  Berkswell 132kV  COVS1L                  132  COVS55J
#
#   Operating Voltage 2 Status Vector Group     R1      X1      X0  Min Tap %  \
# 0                  33    New          xd1  0.503  18.666  15.870      -20.0
# 1                  33    New          xd1  0.502  18.583  15.799      -20.0
# 2                  33    New          xd1  0.394  15.133  17.000      -20.0
# 3                  33    New          xd1  0.394  15.133  17.000      -20.0
# 4                  11    New          xx0  2.241  96.933  82.393      -20.0
#
#    Max Tap %  Nominal Rating  Emergency Rating Reverse Power Capability  \
# ...

# %%
dset3.isnull().sum().sum()
# Out:
# 0

# %%
dset3['Method_of_Earthing'].value_counts()
# Out:
# NER                 1038
# LER                  261
# -                    193
# SR                   185
# Solid                125
# Solid/ET+NER         116
# TR                   116
# R                     79
# Shared ASC            74
# Earth Tx & LER        69
# Earth Tx              63
# ET                    50
# ET + LER              46
# Solid/NER             36
# X                     36
# Solid/ET              26
# TD                    20
# ASC                   15
# D                     14
# T                      5
# ET + ASC               4
# SX                     2
# TX                     2
# Shared LER             2
# Shared ASC / LER       2
# _                      1
# Unearthed              1
# Name: Method_of_Earthing, dtype: int64

# %% [markdown]
# <h1> EDA (Exploratory Data Analysis) </h1>

# %%
dset3["Area"].value_counts()
# Out:
# EMIDS     987
# SWEST     700
# WMIDS     460
# SWALES    434
# Name: Area, dtype: int64

# %%
import plotly.express as px 
ptran= px.histogram(dset3, x = 'Area',  title="Earthing Methods")
ptran.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dset3["Operating Voltage 1"].value_counts()
# Out:
# 33     1874
# 132     569
# 66      138
# Name: Operating Voltage 1, dtype: int64

# %%
import plotly.express as px 
ptran= px.histogram(dset3, x = 'Operating Voltage 1',  title="Voltage Operation")
ptran.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
nof= px.histogram(dset3, x='Area', color="Method_of_Earthing", title="Area / Method of Earthing ")
nof.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
nof= px.histogram(dset3, x='Operating Voltage 1', color="Method_of_Earthing", title="Operating Voltage 1 / Method of Earthing ")
nof.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
pele= ['Area', 'Operating Voltage 1']
cm= sns.light_palette("RED", as_cmap=True)
(round(pd.crosstab(dset3[pele[0]],dset3[pele[1]], normalize='columns') * 100,2)).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_e70d3_row0_col0, #T_e70d3_row0_col2, #T_e70d3_row3_col1 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_e70d3_row0_col1, #T_e70d3_row2_col1, #T_e70d3_row2_col2, #T_e70d3_row3_col0 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_e70d3_row1_col0 {
#   background-color: #f4d0d0;
#   color: #000000;
# }
# #T_e70d3_row1_col1 {
#   background-color: #f6b3b3;
#   color: #000000;
# }
# #T_e70d3_row1_col2 {
#   background-color: #f6adad;
#   color: #000000;
# }
# #T_e70d3_row2_col0 {
#   background-color: #fb5252;
#   color: #f1f1f1;
# }
# #T_e70d3_row3_col2 {
#   background-color: #fa5e5e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e70d3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Operating Voltage 1</th>
#       <th id="T_e70d3_level0_col0" class="col_heading level0 col0" >33</th>
#       <th id="T_e70d3_level0_col1" class="col_heading level0 col1" >66</th>
# ...

# %% [markdown]
# <h1> Now finding categorical columns </h1>

# %%
categorical_values = []
for i in dset3.columns:
    if dset3[i].dtype == "object":
        categorical_values.append(i)
        
print("Categorical columns :", categorical_values)
# Out:
# Categorical columns : ['Area', 'GSP Group', 'Node 1', 'Node 2', 'Operating Voltage 2', 'Status', 'Vector Group', 'Reverse Power Capability', 'Method_of_Earthing']

# %%
from sklearn import preprocessing
le= preprocessing.LabelEncoder()

# %%
for i in categorical_values:
    dset3[i] = le.fit_transform(dset3[i])

# %%
dset3.head()
# Out:
#    Area  GSP Group  Node 1  Operating Voltage 1  Node 2  Operating Voltage 2  \
# 0     0          6     528                  132     465                    4
# 1     0          6     529                  132     466                    4
# 2     0          6     535                  132     471                    4
# 3     0          6     536                  132     472                    4
# 4     0          6     537                  132     473                    0
#
#    Status  Vector Group     R1      X1      X0  Min Tap %  Max Tap %  \
# 0       0            26  0.503  18.666  15.870      -20.0       10.0
# 1       0            26  0.502  18.583  15.799      -20.0       10.0
# 2       0            26  0.394  15.133  17.000      -20.0       10.0
# 3       0            26  0.394  15.133  17.000      -20.0       10.0
# 4       0            28  2.241  96.933  82.393      -20.0       10.0
#
#    Nominal Rating  Emergency Rating  Reverse Power Capability  \
# ...

# %%
dset3.tail()
# Out:
#       Area  GSP Group  Node 1  Operating Voltage 1  Node 2  \
# 2576     3         62    2232                  132    1928
# 2577     3         62    2233                  132    1929
# 2578     3         62    2231                  132    1927
# 2579     3         62    2268                  132    1957
# 2580     3         62    2269                   33    1958
#
#       Operating Voltage 2  Status  Vector Group     R1      X1      X0  \
# 2576                    0       2            26  2.420  85.130  79.000
# 2577                    0       2            26  2.594  69.170  69.170
# 2578                    0       2            26  2.200  90.633  84.067
# 2579                    4       2            26  0.992  21.467  21.467
# 2580                    0       2            31  2.881  76.852   0.000
#
#       Min Tap %  Max Tap %  Nominal Rating  Emergency Rating  \
# 2576      -20.0       10.0            30.0              39.0
# ...

# %%
X= dset3.drop('Method_of_Earthing',axis='columns')
#print(X.shape)
#X
Y= dset3.Method_of_Earthing

# %%
#feature selection using stats Model
import statsmodels.api as sm
X= sm.add_constant(X)

# %%
lr= sm.OLS(Y,X).fit()
print(lr.summary2())
# Out:
#                      Results: Ordinary least squares
# ...
# Model:                OLS                 Adj. R-squared:      0.434
# Dependent Variable:   Method_of_Earthing  AIC:                 14551.6530
# Date:                 2023-05-06 16:58    BIC:                 14651.2039
# No. Observations:     2581                Log-Likelihood:      -7258.8
# Df Model:             16                  F-statistic:         124.5
# Df Residuals:         2564                Prob (F-statistic):  3.39e-305
# R-squared:            0.437               Scale:               16.339
# -------------------------------------------------------------------------
#                           Coef.  Std.Err.    t     P>|t|   [0.025  0.975]
# -------------------------------------------------------------------------
# const                     0.1802   0.6254   0.2881 0.7733 -1.0462  1.4066
# Area                      1.5593   0.1265  12.3244 0.0000  1.3112  1.8074
# ...

# %%
p_values= lr.pvalues
cols= p_values[p_values<=0.05].index.tolist() 
print(cols)
# Out:
# ['Area', 'Operating Voltage 1', 'Operating Voltage 2', 'Vector Group', 'R1', 'X1', 'X0', 'Min Tap %', 'Nominal Rating', 'Emergency Rating']

# %%
X= X[cols[1:]]
X.head()
# Out:
#    Operating Voltage 1  Operating Voltage 2  Vector Group     R1      X1  \
# 0                  132                    4            26  0.503  18.666
# 1                  132                    4            26  0.502  18.583
# 2                  132                    4            26  0.394  15.133
# 3                  132                    4            26  0.394  15.133
# 4                  132                    0            28  2.241  96.933
#
#        X0  Min Tap %  Nominal Rating  Emergency Rating
# 0  15.870      -20.0           120.0             156.0
# 1  15.799      -20.0           120.0             156.0
# 2  17.000      -20.0            90.0             117.0
# 3  17.000      -20.0            90.0             117.0
# 4  82.393      -20.0            30.0              39.0

# %%
Y.head(10)
# Out:
# 0    18
# 1    18
# 2    17
# 3    17
# 4    19
# 5    19
# 6    18
# 7    18
# 8    18
# 9    18
# Name: Method_of_Earthing, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,  Y, test_size = 0.2,random_state = 42)

# %% [markdown]
# <h1> Here Iam checking for the distribution of target variable in Train Test split </h1>

# %%
print('Distribution of target variable in training dataset')
print(Y_train.value_counts())

print('Distribution of target variable in test dataset')
print(Y_test.value_counts())
# Out:
# Distribution of target variable in training dataset
# 9     828
# 8     206
# 11    155
# 0     155
# 16    102
# 18     96
# 22     89
# 10     64
# 13     62
# 7      50
# 6      48
# 3      40
# 5      32
# 25     31
# 19     30
# 17     18
# 21     17
# 2      13
# 1      11
# 20      4
# 4       3
# 15      2
# 23      2
# 14      2
# 12      2
# 26      1
# 24      1
# Name: Method_of_Earthing, dtype: int64
# Distribution of target variable in test dataset
# 9     210
# 8      55
# 0      38
# 11     30
# 22     27
# 16     23
# 18     20
# 7      19
# 6      15
# 10     15
# 5      14
# 13     12
# 3      10
# 17      8
# 19      6
# 25      5
# 1       4
# 21      3
# 2       1
# 4       1
# 20      1
# Name: Method_of_Earthing, dtype: int64

# %% [markdown]
# <h1>Data Normalisation </h1>

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X_train= sc.fit_transform(X_train)
X_test= sc.transform(X_test)

# %% [markdown]
# <h1> Decision Tree </h1>

# %% [markdown]
# SkLearn_DT

# %%
from sklearn.tree import DecisionTreeClassifier

# create an instance of the DecisionTreeClassifier class
clf= DecisionTreeClassifier(max_depth= 4,random_state= 42)
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
predY= clf.predict(X_test)
"""### *Accuracy Score*"""

from sklearn.metrics import accuracy_score,f1_score
print("Model Accuracy: {0}%".format(accuracy_score(Y_test, predY)))
print("f1_score ",f1_score(Y_test, predY,average='weighted'))
# Out:
# Model Accuracy: 0.6286266924564797%
# f1_score  0.5351529527181794

# %% [markdown]
# XGBoost_DT

# %%
from xgboost import XGBClassifier

# Create an instance of XGBClassifier
xgb_clf= XGBClassifier(max_depth= 4,random_state= 42)
xgb_clf.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
predY = xgb_clf.predict(X_test)
"""### *Accuracy Score*"""

from sklearn.metrics import accuracy_score,f1_score
print("Model Accuracy: {0}%".format(accuracy_score(Y_test, predY)))
print("f1_score ",f1_score(Y_test, predY,average='weighted'))
# Out:
# Model Accuracy: 0.7911025145067698%
# f1_score  0.7732648170603517

# %% [markdown]
# <h1> Random Forest </h1>

# %% [markdown]
# XGBoost_RF

# %%
from xgboost import XGBRFClassifier
rfxb= XGBRFClassifier(n_estimators=100, max_depth=4)
rfxb.fit(X_train,Y_train)
# Out:
# XGBRFClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bytree=None,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=4, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 objective='multi:softprob', predictor=None, random_state=None,
#                 reg_alpha=None, ...)

# %%
predY= rfxb.predict(X_test)
"""### *Accuracy Score*"""

from sklearn.metrics import accuracy_score, f1_score
print("Model Accuracy: {0}%".format(accuracy_score(Y_test, predY)))
print("f1_score ",f1_score(Y_test, predY,average='weighted'))
# Out:
# Model Accuracy: 0.6847195357833655%
# f1_score  0.616804043802706

# %% [markdown]
# SKLearn_RF

# %%
from sklearn.ensemble import RandomForestClassifier

# create an instance of the DecisionTreeClassifier class
clf_RF= RandomForestClassifier(n_estimators=100, max_depth=4)
clf_RF.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(max_depth=4)

# %%
predY= clf_RF.predict(X_test)
"""### *Accuracy Score*"""

from sklearn.metrics import accuracy_score,f1_score
print("Model Accuracy: {0}%".format(accuracy_score(Y_test, predY)))
print("f1_score ",f1_score(Y_test, predY,average='weighted'))
# Out:
# Model Accuracy: 0.6518375241779497%
# f1_score  0.5688428922765435
